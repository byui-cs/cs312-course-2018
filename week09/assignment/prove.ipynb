# %% [markdown]
# ![](../../images/cs312.png)
# ***
#
# # 09 Prove - Assignment

# %% [markdown]
# ***
# ## 1 - Objectives
#
# - Impliment flood fill function
# - Impliment the translate() function

# %% [markdown]
# ***
# ## 2 - Introduction
#
# In computer graphics, it is usefull to draw a surface (closed ploygon) and fill it in using a solid color.  This assignment will ask you to impliment a flood fill alogrithm to color a closed area.
#
# **Reading Resources**
#
# - [Flood Fill](https://en.wikipedia.org/wiki/Flood_fill)

# %% [markdown]
# ***
# ## 3 - Assignment
#
# Note that for this assignment, your Crush class can only draw on the screen using the "\_displayPixel()" function.
#
# Add the following code to your Crush class for project 08 (Note that you must use the graphics.py file for this project found in GtiHub):

# %% [markdown]
# ### 3.1 - Flood Fill Function
#
# 1. Add the function **floodfill(x, y, color)** in your Crush class.
#     - **x** is X-Axis location
#     - **y** is Y-Axis location
#     - **color** is the fill color
# 1. You will be implimenting a flood fill in 4 directions.
# 1. You should impliment this algorithm using a stack instead of recursion, however, you can choose.
# 1. This function will then fill in the "space" or "area" that is bounding the position (x, y).
# 1. Note that your function will need to take care of situations where (x, y) is not bound.  In this case, stop filling when you reach the sides of the screen.
# 1. Use the function "self.win.isPixelOn()" to help you know if a pixel is on/off on the screen.
# 1. Make sure you comment your function.
#
# Because of speed issues, you should flush the graphics to the screen now and then.  Use the following code in your fill function to update the graphics.  You can modify this code if you need to do any testing of your function (ie., slow it down).  Remember, that you are only using the \_displayPixel() function to draw.
#
# ```Python
# count += 1
# if (count % 100 == 0):
#     self.flush()
# ```

# %% [markdown]
# ### 3.2 - Translate Function
#
# 1. Add the function **translate(x, y)** to your Crush class.
#     - **x** is the offset in X-Axis
#     - **y** is the offset in Y-Axis
# 1. By default, the graphics window used by Crush is located at the top-left of the window.
# 1. This function will allow you to change the location of (0, 0) that will be used for drawing.  All drawing methods in Crush will use this offset.
# 1. Make sure you comment your function.

# %% [markdown]
# ### 3.3 - Testing your Functions
#
# Use the file project09.py to test your functions.  Do not edit this file.

# %% [markdown]
# ### 3.4 - Resulting Graphics
#
# **Outline drawing with translate() implimented**
#
# ![](flagoutline.jpg)
#
#
#
# **Resulting graphics with floodfill() implimented**
#
# ![](flagcolor.jpg)

# %% [markdown]
# ***
# ## 4 - Rubric
#
# It is your responsibility to show that your assignment clearly satisfies the rubric.  Use as many tests to show that your assignment deserves the grade it should get.
#
# | Task | Points |
# |------|-----|
# | Flood Fill function | 80 |
# | translate | 20 |
# |------|-----|
# | Total | 100  |

# %% [markdown]
# ***
# ## 5 - Submission
#
# - ZIP all files for your project and upload the ZIP file to I-Learn.
